# %%
import glob
import numpy as np
import cv2
IMG_SIZE = 227

# %%
def load_dataset(path):
    X = np.array([])
    y = np.array([])
    classes = ['NORMAL', 'PNEUMONIA']
    for c in classes:
        files = glob.glob(path +c+ '/*.jpeg')
        for f in files:
            print(f)
            img = cv2.imread(f)
            img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
            if X.size == 0:
                X = np.array([img])
            else:
                X = np.vstack((X, [img]))
                y = np.append(y, c)
    assert(X.size>0),'Cannot read file'
    return X, y

# %%
path_train = 'D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/'
path_test = 'D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/'
dev_path = 'D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/'

# %%
X_train , y_train = load_dataset(path_train)
# Out:
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0115-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0117-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0119-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0122-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0125-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0127-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0128-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0129-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0131-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0133-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/train/NORMAL\IM-0135-0001.jpeg
# ...

# %%
X_test, y_test = load_dataset(path_test)
# Out:
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0001-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0003-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0005-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0006-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0007-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0009-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0010-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0011-0001-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0011-0001-0002.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0011-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/test/NORMAL\IM-0013-0001.jpeg
# ...

# %%
X_dev, y_dev = load_dataset(dev_path)
# Out:
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1427-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1430-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1431-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1436-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1437-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1438-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1440-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/NORMAL\NORMAL2-IM-1442-0001.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/PNEUMONIA\person1946_bacteria_4874.jpeg
# D:/Coding/jptNB/HocMayThongKe/lab6/archive/chest_xray/val/PNEUMONIA\person1946_bacteria_4875.jpeg
# ...

# %%
#saving above data
np.save('X_train.npy', X_train)
np.save('y_train.npy', y_train)
np.save('X_test.npy', X_test)
np.save('y_test.npy', y_test)
np.save('X_dev.npy', X_dev)
np.save('y_dev.npy', y_dev)

# %% [markdown]
# ## Bài 1: Hãy đọc dữ liệu, và cho biết các thông tin sau:

# %% [markdown]
# # a) Mục tiêu/ tác vụ mà bộ dữ liệu hướng tới là gì?

# %% [markdown]
# Mục tiêu mà bộ dữ liệu hướng tới:</br> là để phân tích hình ảnh X-Quang ngực, tất cả các chụp X-quang ngực được sàng lọc ban đầu để kiểm soát chất lượng bằng cách loại bỏ tất cả các quét chất lượng thấp hoặc không đọc được. Sau đó, các chẩn đoán cho các hình ảnh được đánh giá bởi hai bác sĩ chuyên môn trước khi được phê duyệt để huấn luyện hệ thống trí tuệ nhân tạo. Để đảm bảo tính chính xác của các chẩn đoán, tập đánh giá cũng được kiểm tra bởi một chuyên gia thứ ba.

# %% [markdown]
# # b) Kích thước của dữ liệu là bao nhiêu trên các tập train, dev và test?

# %%
print('X_train shape: ', X_train.shape)
print('y_train shape: ', y_train.shape)
# Out:
# X_train shape:  (5216, 227, 227, 3)
# y_train shape:  (5216,)

# %%
print('X_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_test shape:  (624, 227, 227, 3)
# y_test shape:  (624,)

# %%
print('X_dev shape: ', X_dev.shape)
print('y_dev shape: ', y_dev.shape)
# Out:
# X_dev shape:  (16, 227, 227, 3)
# y_dev shape:  (16,)

# %%
X_train = np.load(r'Data\X_train.npy')
y_train = np.load(r'Data\y_train.npy')
X_test = np.load(r'Data\X_test.npy')
y_test = np.load(r'Data\y_test.npy')
X_dev = np.load(r'Data\X_dev.npy')  
y_dev = np.load(r'Data\y_dev.npy')

# %% [markdown]
# # c) Phân bố nhãn theo từng tác vụ trên các tập train, dev và test. Vẽ biểu đồ barplot </br>
# # thể hiện phân bố nhãn trên từng tập dữ liệu.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
y_train_df = pd.DataFrame(y_train, columns=['label'])

# %%
y_test_df = pd.DataFrame(y_test, columns=['label'])
y_dev_df = pd.DataFrame(y_dev, columns=['label'])

# %%
fig, ax = plt.subplots(1,3, figsize=(20,10))
sns.barplot(x=y_train_df.label.value_counts().index, y= y_train_df.label.value_counts(), data = y_train_df, ci=None, ax = ax[0]).set(title='Train')
sns.barplot(x=y_test_df.label.value_counts().index, y= y_test_df.label.value_counts(), data = y_test_df, ci=None, ax = ax[1]).set(title='Test')
sns.barplot(x=y_dev_df.label.value_counts().index, y= y_dev_df.label.value_counts(), data = y_dev_df, ci=None, ax = ax[2]).set(title='Dev')
# Out:
# C:\Users\marsen\AppData\Local\Temp\ipykernel_16464\3460160914.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=y_train_df.label.value_counts().index, y= y_train_df.label.value_counts(), data = y_train_df, ci=None, ax = ax[0]).set(title='Train')
# C:\Users\marsen\AppData\Local\Temp\ipykernel_16464\3460160914.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=y_test_df.label.value_counts().index, y= y_test_df.label.value_counts(), data = y_test_df, ci=None, ax = ax[1]).set(title='Test')
# C:\Users\marsen\AppData\Local\Temp\ipykernel_16464\3460160914.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=y_dev_df.label.value_counts().index, y= y_dev_df.label.value_counts(), data = y_dev_df, ci=None, ax = ax[2]).set(title='Dev')
# [Text(0.5, 1.0, 'Dev')]

# %% [markdown]
# # d) Hãy hiển thị khoảng 3 bức hình về ảnh X-Quang phổi lên màn hình

# %%
#show 3 images from train set with different labels
fig, ax = plt.subplots(1,3, figsize=(20,10))
while True:
    i = np.random.randint(0, X_train.shape[0])
    if y_train[i] == 'NORMAL':
        ax[0].imshow(X_train[i])
        ax[0].set_title(y_train[i])
        break
count = 1
while True:
    i = np.random.randint(0, X_train.shape[0])
    if y_train[i] == 'PNEUMONIA':
        ax[count].imshow(X_train[i])
        ax[count].set_title(y_train[i])
        count+=1
        if count > 2:
            break

# %% [markdown]
# ## Bài 2: Huấn luyện mô hình bằng phương pháp Logistic Regression.

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)
X_dev_flat = X_dev.reshape(X_dev.shape[0], -1)

# %%
logreg = LogisticRegression()
logreg.fit(X_train_flat, y_train)
y_pred = logreg.predict(X_test_flat)
# Out:
# c:\Users\marsen\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.33      0.49       234
#    PNEUMONIA       0.71      0.98      0.82       390
#
#     accuracy                           0.74       624
#    macro avg       0.82      0.66      0.66       624
# weighted avg       0.79      0.74      0.70       624

# %% [markdown]
# ## Bài 3: Huấn luyện mô hình bằng phương pháp SVM.

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(X_train_flat, y_train)
y_pred_svc = svc.predict(X_test_flat)

# %%
print(classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.95      0.38      0.54       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.84      0.68      0.69       624
# weighted avg       0.81      0.76      0.72       624

# %% [markdown]
# ## Bài 4: Hãy so sánh kết quả thực hiện giữa 2 phương pháp phân lớp trên. Phương pháp </br>
# ## nào cho kết quả tốt hơn.

# %%
y_test_df = pd.DataFrame(y_test, columns=['label'])

# %%
y_test_df.describe()
# Out:
#             label
# count         624
# unique          2
# top     PNEUMONIA
# freq          390

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.33      0.49       234
#    PNEUMONIA       0.71      0.98      0.82       390
#
#     accuracy                           0.74       624
#    macro avg       0.82      0.66      0.66       624
# weighted avg       0.79      0.74      0.70       624

# %%
print(classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.95      0.38      0.54       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.84      0.68      0.69       624
# weighted avg       0.81      0.76      0.72       624

# %% [markdown]
# Ở model Logreg, ta thấy rằng precision cho label NORMAL là 0.93, nghĩa là hầu hết những dự đoán được cho là NORMAL thì hầu như là NORMAL </br>
# Tuy nhiên ở recall chỉ có 0.33 nghĩa là model đã dự đoán thiếu đi kha khá những bệnh nhân bình thường </br>
# Đối với label PNEUMONIA thì recall lại là 0.98, rất cao nghĩa là model đã dự đoán đúng hầu hết những bệnh nhân bị bệnh này </br>
# trong trường hợp model được sử dụng để dự đoán bệnh thì ta ưu tiên recall hơn (để không bị sót bệnh nhân bị bệnh) </br>
# Tuy vậy cũng cần phải cải thiện ở label NORMAL để giảm thiểu số lượng bệnh nhân bình thường bị dự đoán là bị bệnh </br>

# %% [markdown]
# Ở model SVM, tương tự logreg, ta thấy precision của label NORMAL là rất cao 0.95, nghĩa là hầu hết những dự đoán được cho là NORMAL thì hầu như là NORMAL </br>
# Tuy nhiên cũng tương tự logreg, recall chỉ có 0.38 nghĩa là model đã dự đoán thiếu đi kha khá những bệnh nhân bình thường </br>
# Đối với label PNEUMONIA thì recall lại là 0.99, rất cao nghĩa là model đã dự đoán đúng hầu hết những bệnh nhân bị bệnh này </br>
# Tương tự model logreg, model SVM cũng cần phải cải thiện ở label NORMAL để giảm thiểu số lượng bệnh nhân bình thường bị dự đoán là bị bệnh </br>

# %% [markdown]
# Ở 2 model đều có sự tương đồng về precision và recall của label NORMAL và PNEUMONIA, tuy nhiên model SVM lại có độ chính xác cao hơn model logreg </br>
